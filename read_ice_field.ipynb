# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size':14})
import cmocean.cm as cm
import os
import re

# %%
config = '256_1x4_1000'
ice, area, snow, uice, vice, uwind, vwind, uocean, vocean = np.load(f'out_gpu/out_scale_dx/file_{config}.npy')

# %%
var = area

plt.pcolormesh(var.T, cmap=cm.ice, vmin=0.75)
plt.colorbar()
